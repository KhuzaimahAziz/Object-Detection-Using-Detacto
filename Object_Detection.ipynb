# %% [markdown]
# <a href="https://colab.research.google.com/github/KhuzaimahAziz/ds_task_3/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install detecto
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from detecto import core, utils, visualize
from detecto.visualize import show_labeled_image, plot_prediction_grid
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
custom_transforms = transforms.Compose([
transforms.ToPILImage(),
transforms.Resize(900),
transforms.RandomHorizontalFlip(0.5),
transforms.ColorJitter(saturation=0.2),
transforms.ToTensor(),
utils.normalize_transform(),
])

# %%
Train_dataset=core.Dataset('/content/drive/MyDrive/Object Detection/Train',transform=custom_transforms)#L1
Test_dataset = core.Dataset('/content/drive/MyDrive/Object Detection/Train')#L2
loader=core.DataLoader(Train_dataset, batch_size=2, shuffle=True)#L3
model = core.Model(['Memory'])#L4
losses = model.fit(loader, Test_dataset, epochs=25, lr_step_size=5, learning_rate=0.01, verbose=True)
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1 of 25
# Begin iterating over training dataset
# 100%|██████████| 8/8 [00:04<00:00,  1.86it/s]
# Begin iterating over validation dataset
# 100%|██████████| 15/15 [00:03<00:00,  4.63it/s]
# Loss: 0.31428835590680443
# Epoch 2 of 25
# Begin iterating over training dataset
# 100%|██████████| 8/8 [00:04<00:00,  1.93it/s]
# ...

# %%
plt.plot(losses)
plt.show()

# %%
model.save('model_weights.pth')
model = core.Model.load('model_weights.pth', ['Memory'])

# %%
image = utils.read_image('/content/drive/MyDrive/Object Detection/Test/out16.png') 
predictions = model.predict(image)
labels, boxes, scores = predictions
show_labeled_image(image, boxes, labels)

# %%
thresh=0.8
filtered_indices=np.where(scores>thresh)
filtered_scores=scores[filtered_indices]
filtered_boxes=boxes[filtered_indices]
num_list = filtered_indices[0].tolist()
filtered_labels = [labels[i] for i in num_list]
show_labeled_image(image, filtered_boxes, filtered_labels)

# %%
print(filtered_boxes)
# Out:
# tensor([[ 721.5281,  580.0993, 1343.0128,  811.1884],
#         [ 551.3067,  276.5998, 1118.6693,  476.5688],
#         [1548.3931,  636.7108, 1771.4076,  877.4103]])
